# %%
# Simple Python code to display text 
print("Hello, Jupyter!")
# Out:
# Hello, Jupyter!

# %%
import datetime

# %%
birth_date = datetime.date(1998,12,2)

# %%
today = datetime.date.today()

# %%
delta = today - birth_date
age_in_days = delta.days

# %%
print(age_in_days)
# Out:
# 9951
